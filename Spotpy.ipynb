# %% [markdown]
# # Gnod Project

# %% [markdown]
# ## Importing libraries

# %%
import spotipy
import spotipy.oauth2 as oauth2
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time

# %% [markdown]
# ## Conenct to the Spotify API

# %%
sp = spotipy.Spotify(auth_manager = SpotifyClientCredentials(client_id = '2ccfc9245cd046ffa717955ce67f7829',
                                       client_secret = 'ee015a82d7894239b37bd8986a8fdbd8'))

# %%
playlist = sp.user_playlist_tracks("spotify", "6yPiKpy7evrwvZodByKvM9")

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/6yPiKpy7evrwvZodByKvM9/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2017-02-27T01:38:09Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#     'href': 'https://api.spotify.com/v1/users/12160726861',
#     'id': '12160726861',
#     'type': 'user',
#     'uri': 'spotify:user:12160726861'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/50Lr1puweM1hFsF1LpIZLM'},
#        'href': 'https://api.spotify.com/v1/artists/50Lr1puweM1hFsF1LpIZLM',
#        'id': '50Lr1puweM1hFsF1LpIZLM',
#        'name': 'WhoMadeWho',
#        'type': 'artist',
#        'uri': 'spotify:artist:50Lr1puweM1hFsF1LpIZLM'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1cS5EoXVqz7aON00AkVBBA'},
# ...

# %%
playlist["total"]
# Out:
# 10000

# %%
playlist['items'][0]['track']['uri']
# Out:
# 'spotify:track:33xMbeHzmWd6Od0BmLZEUs'

# %%
for value in range(5):
    print(playlist['items'][value]['track']['uri'])
# Out:
# spotify:track:33xMbeHzmWd6Od0BmLZEUs
# spotify:track:3UnyplmZaq547hwsfOR5yy
# spotify:track:1w8QCSDH4QobcQeT4uMKLm
# spotify:track:7J9mBHG4J2eIfDAv5BehKA
# spotify:track:1VZedwJj1gyi88WFRhfThb

# %%
sp.audio_features('spotify:track:33xMbeHzmWd6Od0BmLZEUs')
# Out:
# [{'danceability': 0.31,
#   'energy': 0.445,
#   'key': 7,
#   'loudness': -13.355,
#   'mode': 0,
#   'speechiness': 0.0863,
#   'acousticness': 0.094,
#   'instrumentalness': 0.0678,
#   'liveness': 0.113,
#   'valence': 0.122,
#   'tempo': 95.36,
#   'type': 'audio_features',
#   'id': '33xMbeHzmWd6Od0BmLZEUs',
#   'uri': 'spotify:track:33xMbeHzmWd6Od0BmLZEUs',
#   'track_href': 'https://api.spotify.com/v1/tracks/33xMbeHzmWd6Od0BmLZEUs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/33xMbeHzmWd6Od0BmLZEUs',
#   'duration_ms': 152560,
#   'time_signature': 3}]

# %%
audio_features = sp.audio_features('spotify:track:33xMbeHzmWd6Od0BmLZEUs')

# %%
audio_features
# Out:
# [{'danceability': 0.31,
#   'energy': 0.445,
#   'key': 7,
#   'loudness': -13.355,
#   'mode': 0,
#   'speechiness': 0.0863,
#   'acousticness': 0.094,
#   'instrumentalness': 0.0678,
#   'liveness': 0.113,
#   'valence': 0.122,
#   'tempo': 95.36,
#   'type': 'audio_features',
#   'id': '33xMbeHzmWd6Od0BmLZEUs',
#   'uri': 'spotify:track:33xMbeHzmWd6Od0BmLZEUs',
#   'track_href': 'https://api.spotify.com/v1/tracks/33xMbeHzmWd6Od0BmLZEUs',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/33xMbeHzmWd6Od0BmLZEUs',
#   'duration_ms': 152560,
#   'time_signature': 3}]

# %%
audio_features[0]

#aqui estoy accediendo al diccionario dentro de la lista
# Out:
# {'danceability': 0.31,
#  'energy': 0.445,
#  'key': 7,
#  'loudness': -13.355,
#  'mode': 0,
#  'speechiness': 0.0863,
#  'acousticness': 0.094,
#  'instrumentalness': 0.0678,
#  'liveness': 0.113,
#  'valence': 0.122,
#  'tempo': 95.36,
#  'type': 'audio_features',
#  'id': '33xMbeHzmWd6Od0BmLZEUs',
#  'uri': 'spotify:track:33xMbeHzmWd6Od0BmLZEUs',
#  'track_href': 'https://api.spotify.com/v1/tracks/33xMbeHzmWd6Od0BmLZEUs',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/33xMbeHzmWd6Od0BmLZEUs',
#  'duration_ms': 152560,
#  'time_signature': 3}

# %%
audio_features[0].keys()
# Out:
# dict_keys(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms', 'time_signature'])

# %%
list(audio_features[0].values())
# Out:
# [0.31,
#  0.445,
#  7,
#  -13.355,
#  0,
#  0.0863,
#  0.094,
#  0.0678,
#  0.113,
#  0.122,
#  95.36,
#  'audio_features',
#  '33xMbeHzmWd6Od0BmLZEUs',
#  'spotify:track:33xMbeHzmWd6Od0BmLZEUs',
#  'https://api.spotify.com/v1/tracks/33xMbeHzmWd6Od0BmLZEUs',
#  'https://api.spotify.com/v1/audio-analysis/33xMbeHzmWd6Od0BmLZEUs',
#  152560,
#  3]

# %%
# Loop for getting all the uris from the playlist 
for uris in range(len(playlist['items'])):
    print(playlist['items'][uris]['track']['uri'])
# Out:
# spotify:track:33xMbeHzmWd6Od0BmLZEUs
# spotify:track:3UnyplmZaq547hwsfOR5yy
# spotify:track:1w8QCSDH4QobcQeT4uMKLm
# spotify:track:7J9mBHG4J2eIfDAv5BehKA
# spotify:track:1VZedwJj1gyi88WFRhfThb
# spotify:track:3DSmOF7ETJHAQEqqgoSJao
# spotify:track:5HPnumlogzZtpLEaORZjz1
# spotify:track:6i99ThziImjuFABb8rUQvy
# spotify:track:0nkLI0pdyTRpq7BsTFBufZ
# spotify:track:6Yu1OL8I0D4vjOzYdsXYGK
# spotify:track:2HvTGx5fzFGpHSyRNvXd9T
# spotify:track:2XS4lIQ1bl9KSNsYtkqK46
# spotify:track:6dsq7Nt5mIFzvm5kIYNORy
# spotify:track:1wKGGfnznnXIvupuEZt9mM
# spotify:track:7Jjqx75QRHaYsxF5WnHovC
# spotify:track:7BIPYQPHbPVDE9UsA0eT72
# spotify:track:4KEw5m7CZXVbpWbHVK4OrV
# spotify:track:2YTRLoG5jdzCp4yg3B6OnH
# spotify:track:5MPryR3oJGmWnSYM7X2GGE
# spotify:track:4ymUtICOpIlyvFf3URM7XZ
# spotify:track:2lffRiAET2Xt6BNb4EmkS2
# spotify:track:3oQ52Mqz2ih8KjligVoQrG
# spotify:local:::100+Amazing+Bass+Lines:785
# spotify:track:5h8G81Ls00kyf1UEen0gBB
# spotify:track:6Tq4LginUMBOgZrUs8M40h
# ...

# %%
# Loop for getting all the features from the playlist 
for features in range(len(audio_features)):
    print(audio_features[features].values())
# Out:
# dict_values([0.31, 0.445, 7, -13.355, 0, 0.0863, 0.094, 0.0678, 0.113, 0.122, 95.36, 'audio_features', '33xMbeHzmWd6Od0BmLZEUs', 'spotify:track:33xMbeHzmWd6Od0BmLZEUs', 'https://api.spotify.com/v1/tracks/33xMbeHzmWd6Od0BmLZEUs', 'https://api.spotify.com/v1/audio-analysis/33xMbeHzmWd6Od0BmLZEUs', 152560, 3])

# %%
uris_list = list()

while playlist['next']:
    
    for uris in range(len(playlist['items'])):
        uris_list.append(playlist['items'][uris]['track']['uri'])

    playlist = sp.next(playlist)

# %%
uris_list
# Out:
# ['spotify:track:33xMbeHzmWd6Od0BmLZEUs',
#  'spotify:track:3UnyplmZaq547hwsfOR5yy',
#  'spotify:track:1w8QCSDH4QobcQeT4uMKLm',
#  'spotify:track:7J9mBHG4J2eIfDAv5BehKA',
#  'spotify:track:1VZedwJj1gyi88WFRhfThb',
#  'spotify:track:3DSmOF7ETJHAQEqqgoSJao',
#  'spotify:track:5HPnumlogzZtpLEaORZjz1',
#  'spotify:track:6i99ThziImjuFABb8rUQvy',
#  'spotify:track:0nkLI0pdyTRpq7BsTFBufZ',
#  'spotify:track:6Yu1OL8I0D4vjOzYdsXYGK',
#  'spotify:track:2HvTGx5fzFGpHSyRNvXd9T',
#  'spotify:track:2XS4lIQ1bl9KSNsYtkqK46',
#  'spotify:track:6dsq7Nt5mIFzvm5kIYNORy',
#  'spotify:track:1wKGGfnznnXIvupuEZt9mM',
#  'spotify:track:7Jjqx75QRHaYsxF5WnHovC',
#  'spotify:track:7BIPYQPHbPVDE9UsA0eT72',
#  'spotify:track:4KEw5m7CZXVbpWbHVK4OrV',
#  'spotify:track:2YTRLoG5jdzCp4yg3B6OnH',
#  'spotify:track:5MPryR3oJGmWnSYM7X2GGE',
#  'spotify:track:4ymUtICOpIlyvFf3URM7XZ',
#  'spotify:track:2lffRiAET2Xt6BNb4EmkS2',
#  'spotify:track:3oQ52Mqz2ih8KjligVoQrG',
#  'spotify:local:::100+Amazing+Bass+Lines:785',
# ...

# %%
total_audio_features = list()

for uri in (uris_list):
    audio_features = sp.audio_features(uri)
    if audio_features != [None]:
        total_audio_features.append(list(audio_features[0].values()))
# Out:
# Expected id of type track but found type 100+Amazing+Bass+Lines spotify:local:::100+Amazing+Bass+Lines:785
# Expected id of type track but found type Alabama+Shakes+performing+Don%27t+Wanna+Fight+Live+on+KCRW spotify:local:::Alabama+Shakes+performing+Don%27t+Wanna+Fight+Live+on+KCRW:251
# Expected id of type track but found type Anderson+East+-+Satisfy+Me+-+3_15_2015+-+Riverview+Bungalow%2C+Austin%2C+TX spotify:local:::Anderson+East+-+Satisfy+Me+-+3_15_2015+-+Riverview+Bungalow%2C+Austin%2C+TX:164
# Expected id of type track but found type Art+Of+Sleeping+cover+Drake+%27Hotline+Bling%27+for+Like+A+Version spotify:local:::Art+Of+Sleeping+cover+Drake+%27Hotline+Bling%27+for+Like+A+Version:281
# Expected id of type track but found type Bahamas+-+Stronger+Than+That+%28Buzzsession%29 spotify:local:::Bahamas+-+Stronger+Than+That+%28Buzzsession%29:172
# ...

# %%
total_audio_features_df = pd.DataFrame(data = total_audio_features, columns = list(audio_features[0].keys()))

# %%
total_audio_features_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.310   0.445    7   -13.355     0       0.0863       0.09400
# 1            0.419   0.565    5   -11.565     1       0.0347       0.13700
# 2            0.354   0.302    9   -13.078     1       0.0326       0.59000
# 3            0.727   0.785    5    -6.707     0       0.0603       0.32500
# 4            0.571   0.724    0    -5.967     1       0.0260       0.02310
# ...            ...     ...  ...       ...   ...          ...           ...
# 9813         0.167   0.110   11   -27.323     0       0.0489       0.99000
# 9814         0.791   0.619    1    -5.886     1       0.0532       0.00784
# 9815         0.663   0.713    7    -6.647     0       0.1120       0.03530
# 9816         0.725   0.534   11    -6.238     1       0.0946       0.07520
# 9817         0.628   0.698    6    -5.608     0       0.1050       0.04720
#
# ...

# %%
total_audio_features_df.to_csv('Audio_features.csv', index = False)

# %% [markdown]
# # Clusters

# %%
from sklearn.cluster import KMeans
import numpy as np

# %%
numeric_audio_features = total_audio_features_df.select_dtypes(include = np.number)

# %%
numeric_audio_features
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.310   0.445    7   -13.355     0       0.0863       0.09400
# 1            0.419   0.565    5   -11.565     1       0.0347       0.13700
# 2            0.354   0.302    9   -13.078     1       0.0326       0.59000
# 3            0.727   0.785    5    -6.707     0       0.0603       0.32500
# 4            0.571   0.724    0    -5.967     1       0.0260       0.02310
# ...            ...     ...  ...       ...   ...          ...           ...
# 9813         0.167   0.110   11   -27.323     0       0.0489       0.99000
# 9814         0.791   0.619    1    -5.886     1       0.0532       0.00784
# 9815         0.663   0.713    7    -6.647     0       0.1120       0.03530
# 9816         0.725   0.534   11    -6.238     1       0.0946       0.07520
# 9817         0.628   0.698    6    -5.608     0       0.1050       0.04720
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# ...

# %%
inertia_list = list()
clusters = list(range(2,10))

for c in clusters:
    kmeans = KMeans(n_clusters=c, random_state=0).fit(numeric_audio_features)
    inertia_list.append(round(kmeans.inertia_, 2))

# %%
clusters
# Out:
# [2, 3, 4, 5, 6, 7, 8, 9]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig = plt.figure(figsize = (12, 8))
plt.plot(clusters, (inertia_list)) 
plt.title('Elbow plot', fontsize = 15)
plt.show()

# %%
final_kmeans = KMeans(n_clusters=4, random_state=0).fit(numeric_audio_features)

# %%
numeric_audio_features['cluster'] = final_kmeans.predict(numeric_audio_features)
# Out:
# /var/folders/x0/lydc794d7tjbpf7r4sygzwrw0000gn/T/ipykernel_40487/1993461192.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numeric_audio_features['cluster'] = final_kmeans.predict(numeric_audio_features)

# %%
numeric_audio_features
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.310   0.445    7   -13.355     0       0.0863       0.09400
# 1            0.419   0.565    5   -11.565     1       0.0347       0.13700
# 2            0.354   0.302    9   -13.078     1       0.0326       0.59000
# 3            0.727   0.785    5    -6.707     0       0.0603       0.32500
# 4            0.571   0.724    0    -5.967     1       0.0260       0.02310
# ...            ...     ...  ...       ...   ...          ...           ...
# 9813         0.167   0.110   11   -27.323     0       0.0489       0.99000
# 9814         0.791   0.619    1    -5.886     1       0.0532       0.00784
# 9815         0.663   0.713    7    -6.647     0       0.1120       0.03530
# 9816         0.725   0.534   11    -6.238     1       0.0946       0.07520
# 9817         0.628   0.698    6    -5.608     0       0.1050       0.04720
#
#       instrumentalness  liveness  valence    tempo  duration_ms  \
# ...

# %%
#song_data = sp.search(q = 'Peaches', type = "track", limit = 1)

# %%
#song_uri = song_data['tracks']['items'][0]['uri']

# %%
#song_features = sp.audio_features(song_uri)

# %%
#song_features = song_features[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/x0/lydc794d7tjbpf7r4sygzwrw0000gn/T/ipykernel_40487/111653785.py in <module>
# ----> 1 song_features = song_features[0]
#
# KeyError: 0

# %%
# song_features_df = pd.DataFrame([song_features.values()], columns = song_features.keys())

# %%
# numeric_song_features = song_features_df.select_dtypes(include = np.number)

# %%
# numeric_song_features_cluster = final_kmeans.predict(numeric_song_features)

# %%
# numeric_song_features_cluster[0]
# Out:
# 3

# %%
# def cluster_classification (numeric_audio_features):
    # if numeric_audio_features['cluster'] == 0:
        # return cluster0 = pd.DataFrame[numeric_audio_features]
# Out:
#   File "/var/folders/x0/lydc794d7tjbpf7r4sygzwrw0000gn/T/ipykernel_40487/103893732.py", line 3
#     return cluster0 = pd.DataFrame[numeric_audio_features]
#                     ^
# SyntaxError: invalid syntax

# %%
# cluster0 = pd.DataFrame[numeric_audio_features['cluster']==0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/x0/lydc794d7tjbpf7r4sygzwrw0000gn/T/ipykernel_40487/830886373.py in <module>
# ----> 1 cluster0 = pd.DataFrame[numeric_audio_features['cluster']==0]
#
# TypeError: 'type' object is not subscriptable

# %%
# numeric_audio_features['cluster']==0
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9813     True
# 9814    False
# 9815    False
# 9816    False
# 9817    False
# Name: cluster, Length: 9818, dtype: bool

# %%
# cluster0 = numeric_audio_features[numeric_audio_features['cluster'].str.contains(0)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/x0/lydc794d7tjbpf7r4sygzwrw0000gn/T/ipykernel_40487/1125592377.py in <module>
# ----> 1 cluster0 = numeric_audio_features[numeric_audio_features['cluster'].str.contains(0)]
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5476         ):
#    5477             return self[name]
# -> 5478         return object.__getattribute__(self, name)
#    5479
#    5480     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.9/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
# ...

# %% [markdown]
# 4 dataframes: uno con cada canción de cada cluster
#
# if cluster = 0
# retunr cancion de ese data fram
#
# elif cluster = 1
# return
